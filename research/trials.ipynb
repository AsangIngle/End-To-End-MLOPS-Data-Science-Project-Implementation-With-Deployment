# %%
from box import ConfigBox

# %%
# #!pip install python-box
# python -c "from box import ConfigBox; print('Working')"

# %%
# import sys
# print(sys.executable)
d2=ConfigBox({'key':1,'ke2':2,'key3':4})

# %%
d2.key
# Out:
# 1

# %%
def get_prodict(x:int,y:int)->int:
    return x*y

# %%
get_prodict(2,3)
# Out:
# 6

# %%
get_prodict(2,'2')
# Out:
# '22'

# %%
#so to prevent such un-wanted outptu we use ensure_annotation

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_add(x:int,y:int) ->int:
    return x+y

# %%
get_add(2,2)
# Out:
# 4

# %%
# get_add(2,'2') #through error
